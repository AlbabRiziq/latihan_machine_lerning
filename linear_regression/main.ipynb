# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

style.use('Solarize_Light2')

# %%
X_data = np.array([i+1 for i in range(50)]).reshape(-1, 1)
y_data = np.array([np.random.randint(15, size=50)]).reshape(-1, 1)

# %%
y_data
# Out:
# array([[ 4],
#        [11],
#        [12],
#        [13],
#        [ 5],
#        [ 5],
#        [12],
#        [10],
#        [ 7],
#        [ 1],
#        [ 4],
#        [11],
#        [ 1],
#        [13],
#        [ 1],
#        [ 6],
#        [ 0],
#        [12],
#        [ 0],
#        [11],
#        [10],
#        [ 1],
#        [ 0],
#        [12],
#        [ 0],
#        [ 5],
#        [ 2],
#        [10],
#        [14],
#        [ 5],
#        [ 3],
#        [10],
#        [11],
#        [ 3],
#        [11],
#        [12],
#        [12],
#        [ 3],
#        [ 3],
#        [ 7],
#        [13],
#        [ 9],
#        [13],
#        [ 0],
#        [14],
#        [14],
#        [ 7],
#        [ 9],
#        [ 2],
#        [ 3]])

# %%
plt.scatter(X_data, y_data)
plt.ylim(-2, 20)
plt.xlim(-2, 55)
# Out:
# (-2.0, 55.0)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_data, y_data)
# Out:
# LinearRegression()

# %%
X_vis = np.array([0, 2]).reshape(-1, 1)
y_vis = model.predict(X_vis)

plt.plot(X_data, y_data)
plt.scatter(X_vis, y_vis, c="r")
